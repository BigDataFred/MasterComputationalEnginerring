# %% [markdown]
# # Tema 2. Búsqueda Local y Algoritmo de Enfriamiento Estadístico

# %% [markdown]
# ### En esta clase ejercitaremos los conocimientos relacionados con la formulación de problemas de optimización y su resolución con técnicas de búsqueda local. La práctica persigue afianzar el dominio de los conceptos fundamentales en estos temas y desarrollar las habilidades para resolver estos problemas utilizando técnicas de programación.

# %%
# Comenzamos importando las librerías de python que serán utilizadas para desarrollar los ejercicios,
# lecturas de ficheros, imágenes, etcétera.
import pandas as pd 
import numpy as np
import pylab as pl

from IPython.display import display
from IPython.display import Image

# %%
# Cargamos una imagen que describe una instancia del problema TSP
 
i = Image(filename='images/tsp1.png')
i

# %%
# Para la instancia anterior:

#    Calcule el valor de la solución óptima del problema TSP (suma de las distancias entre ciudades adyacentes 
#    en la solución)  
#    Utilizando la función Check_BestTSP.py compruebe si el valor calculado es el óptimo

# Ejemplo: Comprobaremos si el valor óptimo de la solución es 100

# %run CheckBestTSP.py 100
# Out:
# El valor escogido no es correcto.

# %%
# Importamos una imagen que representa la partición de un grafo de 8 nodos
# en tres grupos
i = Image(filename='images/graph1_rand.png')
i

# %%
# Una posible representación de la partición anterior es
# X = [2 2 2 1 1 1 3 3]

# %%
# A partir del ejemplo de representación anterior escoja una representación para 
# la siguiente partición
i = Image(filename='images/graph1_met.png')
i

# %%
# Compruebe la validez de la representación utilizada con la función
# CheckRepresentation.py
# Ejemplo:
# %run CheckRepresentation.py 1 "[1 1 1 1 3 2 2 3]"
# Out:
# ERROR: File `'CheckRepresentation.py'` not found.

# %%
# Cuántas posibles representaciones pueden obtenerse para la partición en el grafo Out[39]?

# %%
# Escoja una representación para la siguiente partición
i = Image(filename='images/graph1_hash6.png')
i

# %%
# Compruebe la validez de la representación utilizada para la partición Out[41] 
# con la función CheckRepresentation.py
# Ejemplo:
# %run CheckRepresentation.py 2 "[1 1 1 1 3 2 2 3]"
# Out:
# ERROR: File `'CheckRepresentation.py'` not found.
